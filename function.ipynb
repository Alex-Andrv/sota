# %%
import torch
from function.function import Function
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

# %matplotlib notebook

def draw_3d_function(function: Function, min_v: int = -10, max_v: int = 10):
    x_range = torch.linspace(min_v, max_v, 100)
    y_range = torch.linspace(min_v, max_v, 100)
    X, Y = torch.meshgrid(x_range, y_range)
    concatenated_tensor = torch.cat((X.unsqueeze(0), Y.unsqueeze(0)), dim=0)
    result = function.calculate(concatenated_tensor)
    fig = plt.figure()
    ax = fig.add_subplot(111,projection='3d')
    ax.plot_surface(X.numpy(), Y.numpy(), result.numpy(), cmap='viridis')
    # Set labels
    ax.set_xlabel('X')
    ax.set_ylabel('Y')
    ax.set_zlabel('Z')
    # Show the plot
    plt.show()

# %%
from function.middle.matyas import Matyas

draw_3d_function(Matyas(torch.empty(2, 3)), -100, 100)
# Out:
# /Users/alexanderandreev/miniconda3/envs/SOAT/lib/python3.11/site-packages/torch/functional.py:504: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at /Users/runner/miniforge3/conda-bld/pytorch-recipe_1696859376036/work/aten/src/ATen/native/TensorShape.cpp:3484.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]
# <div id='bcdcc301-7d5d-4535-bb42-6f2132282637'></div>

# %%
from function.middle.beale import Beale

draw_3d_function(Beale(torch.empty(2, 3)), -100, 100)
# Out:
# <div id='879e3f7a-2e2d-4201-9ea8-daaecec3b915'></div>

# %%
from function.easy.bohachevsky import Bohachevsky


draw_3d_function(Bohachevsky(torch.empty(2, 3)), -100, 100)
# Out:
# /var/folders/h_/gtpkylsj3_n58zkn01d0wlj80000gn/T/ipykernel_88648/1697605376.py:15: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   ax.scatter(X.numpy(), Y.numpy(), result.numpy(), cmap='viridis')

# %%
from function.easy.vincent import Vincent


draw_3d_function(Vincent(torch.empty(2, 3)), -100, 100)

# %%
from function.easy.quadratic import Quadratic


draw_3d_function(Quadratic(torch.empty(2, 3), torch.tensor([1, 5])), -100000, 100000)

# %%
from function.hard.ackley import Ackley


draw_3d_function(Ackley(torch.empty(2, 3)), -10, 10)

# %%
from function.hard.drop_wave import DropWave

draw_3d_function(DropWave(torch.empty(2, 3)), -10, 10)
